# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Churn_Modelling.csv')

# %%
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
X = dataset.iloc[:,3:13].values
Y = dataset.iloc[:,13].values

# %%
print(X)
# Out:
# [[619 'France' 'Female' ... 1 1 101348.88]
#  [608 'Spain' 'Female' ... 0 1 112542.58]
#  [502 'France' 'Female' ... 1 0 113931.57]
#  ...
#  [709 'France' 'Female' ... 0 1 42085.58]
#  [772 'Germany' 'Male' ... 1 0 92888.52]
#  [792 'France' 'Female' ... 1 0 38190.78]]

# %%
print(Y)
# Out:
# [1 0 1 ... 1 1 0]

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_2 = LabelEncoder()
X[:,2] = labelencoder_X_2.fit_transform(X[:,2])

# %%
print(X)
# Out:
# [[619 'France' 0 ... 1 1 101348.88]
#  [608 'Spain' 0 ... 0 1 112542.58]
#  [502 'France' 0 ... 1 0 113931.57]
#  ...
#  [709 'France' 0 ... 0 1 42085.58]
#  [772 'Germany' 1 ... 1 0 92888.52]
#  [792 'France' 0 ... 1 0 38190.78]]

# %%
from sklearn.compose import ColumnTransformer

# %%
ct = ColumnTransformer([('ohe',OneHotEncoder(),[1])], remainder='passthrough')

# %%
X = np.array(ct.fit_transform(X), dtype = str)

# %%
X = X[:,1:]

# %%
print(X)
# Out:
# [['0.0' '0.0' '619' ... '1' '1' '101348.88']
#  ['0.0' '1.0' '608' ... '0' '1' '112542.58']
#  ['0.0' '0.0' '502' ... '1' '0' '113931.57']
#  ...
#  ['0.0' '0.0' '709' ... '0' '1' '42085.58']
#  ['1.0' '0.0' '772' ... '1' '0' '92888.52']
#  ['0.0' '0.0' '792' ... '1' '0' '38190.78']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print(X_train)
# Out:
# [[-0.5698444   1.74309049  0.16958176 ...  0.64259497 -1.03227043
#    1.10643166]
#  [ 1.75486502 -0.57369368 -2.30455945 ...  0.64259497  0.9687384
#   -0.74866447]
#  [-0.5698444  -0.57369368 -1.19119591 ...  0.64259497 -1.03227043
#    1.48533467]
#  ...
#  [-0.5698444  -0.57369368  0.9015152  ...  0.64259497 -1.03227043
#    1.41231994]
#  [-0.5698444   1.74309049 -0.62420521 ...  0.64259497  0.9687384
#    0.84432121]
#  [ 1.75486502 -0.57369368 -0.28401079 ...  0.64259497 -1.03227043
#    0.32472465]]

# %%
pd.DataFrame(X_train)
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.569844  1.743090  0.169582 -1.091687 -0.464608  0.006661 -1.215717
# 1     1.754865 -0.573694 -2.304559  0.916013  0.301026 -1.377440 -0.006312
# 2    -0.569844 -0.573694 -1.191196 -1.091687 -0.943129 -1.031415  0.579935
# 3    -0.569844  1.743090  0.035566  0.916013  0.109617  0.006661  0.473128
# 4    -0.569844  1.743090  2.056114 -1.091687  1.736588  1.044737  0.810193
# ...        ...       ...       ...       ...       ...       ...       ...
# 7995  1.754865 -0.573694 -0.582970 -1.091687 -0.656016 -0.339364  0.703104
# 7996 -0.569844  1.743090  1.478815 -1.091687 -1.613058 -0.339364  0.613060
# 7997 -0.569844 -0.573694  0.901515  0.916013 -0.368904  0.006661  1.361474
# 7998 -0.569844  1.743090 -0.624205 -1.091687 -0.081791  1.390762 -1.215717
# 7999  1.754865 -0.573694 -0.284011 -1.091687  0.875251 -1.377440  0.511364
#
#             7         8         9         10
# 0     0.809503  0.642595 -1.032270  1.106432
# 1    -0.921591  0.642595  0.968738 -0.748664
# 2    -0.921591  0.642595 -1.032270  1.485335
# 3    -0.921591  0.642595 -1.032270  1.276528
# 4     0.809503  0.642595  0.968738  0.558378
# ...        ...       ...       ...       ...
# 7995  0.809503  0.642595  0.968738  1.091330
# 7996 -0.921591  0.642595  0.968738  0.131760
# 7997  0.809503  0.642595 -1.032270  1.412320
# 7998  0.809503  0.642595  0.968738  0.844321
# 7999 -0.921591  0.642595 -1.032270  0.324725
#
# [8000 rows x 11 columns]

# %%
#pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (2.13.0)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (18.1.1)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.25.8)
# Requirement already satisfied: setuptools in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.40.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.0.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (7.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.20.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\khushi a yadav\.conda\envs\myenv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.models import Sequential

# %%
from keras.layers import Dense

# %%
classifier = Sequential()

# %%
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))

# %%
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# %%
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.fit(X_train, Y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 1s 831us/step - loss: 0.4809 - accuracy: 0.7960
# Epoch 2/100
# 800/800 [==============================] - 1s 698us/step - loss: 0.4289 - accuracy: 0.7960
# Epoch 3/100
# 800/800 [==============================] - 1s 684us/step - loss: 0.4228 - accuracy: 0.7987
# Epoch 4/100
# 800/800 [==============================] - 1s 685us/step - loss: 0.4191 - accuracy: 0.8215
# Epoch 5/100
# 800/800 [==============================] - 1s 693us/step - loss: 0.4163 - accuracy: 0.8278
# Epoch 6/100
# 800/800 [==============================] - 1s 700us/step - loss: 0.4141 - accuracy: 0.8303
# Epoch 7/100
# 800/800 [==============================] - 1s 716us/step - loss: 0.4131 - accuracy: 0.8310
# Epoch 8/100
# 800/800 [==============================] - 1s 726us/step - loss: 0.4108 - accuracy: 0.8317
# Epoch 9/100
# 800/800 [==============================] - 1s 705us/step - loss: 0.4108 - accuracy: 0.8326
# Epoch 10/100
# 800/800 [==============================] - 1s 723us/step - loss: 0.4096 - accuracy: 0.8332
# Epoch 11/100
# 800/800 [==============================] - 1s 732us/step - loss: 0.4078 - accuracy: 0.8338
# Epoch 12/100
# 800/800 [==============================] - 1s 730us/step - loss: 0.4077 - accuracy: 0.8345
# Epoch 13/100
# 800/800 [==============================] - 1s 807us/step - loss: 0.4074 - accuracy: 0.8345
# Epoch 14/100
# 800/800 [==============================] - 1s 872us/step - loss: 0.4065 - accuracy: 0.8345
# Epoch 15/100
# 800/800 [==============================] - 1s 814us/step - loss: 0.4063 - accuracy: 0.8344
# Epoch 16/100
# 800/800 [==============================] - 1s 786us/step - loss: 0.4056 - accuracy: 0.8344
# Epoch 17/100
# 800/800 [==============================] - 1s 761us/step - loss: 0.4051 - accuracy: 0.8345
# Epoch 18/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4044 - accuracy: 0.8345
# Epoch 19/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4044 - accuracy: 0.8329
# Epoch 20/100
# 800/800 [==============================] - 1s 996us/step - loss: 0.4043 - accuracy: 0.8353
# Epoch 21/100
# 800/800 [==============================] - 1s 914us/step - loss: 0.4033 - accuracy: 0.8339
# Epoch 22/100
# 800/800 [==============================] - 1s 782us/step - loss: 0.4037 - accuracy: 0.8342
# Epoch 23/100
# 800/800 [==============================] - 1s 724us/step - loss: 0.4033 - accuracy: 0.8354
# Epoch 24/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4032 - accuracy: 0.8350
# Epoch 25/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4025 - accuracy: 0.8341
# Epoch 26/100
# 800/800 [==============================] - 1s 843us/step - loss: 0.4028 - accuracy: 0.8360
# Epoch 27/100
# 800/800 [==============================] - 1s 754us/step - loss: 0.4028 - accuracy: 0.8349
# Epoch 28/100
# 800/800 [==============================] - 1s 747us/step - loss: 0.4021 - accuracy: 0.8347
# Epoch 29/100
# 800/800 [==============================] - 1s 750us/step - loss: 0.4023 - accuracy: 0.8349
# Epoch 30/100
# 800/800 [==============================] - 1s 744us/step - loss: 0.4017 - accuracy: 0.8349
# Epoch 31/100
# 800/800 [==============================] - 1s 744us/step - loss: 0.4020 - accuracy: 0.8340
# Epoch 32/100
# 800/800 [==============================] - 1s 745us/step - loss: 0.4019 - accuracy: 0.8342
# Epoch 33/100
# 800/800 [==============================] - 1s 729us/step - loss: 0.4020 - accuracy: 0.8355
# Epoch 34/100
# 800/800 [==============================] - 1s 722us/step - loss: 0.4018 - accuracy: 0.8342
# Epoch 35/100
# 800/800 [==============================] - 1s 733us/step - loss: 0.4012 - accuracy: 0.8349
# Epoch 36/100
# 800/800 [==============================] - 1s 736us/step - loss: 0.4017 - accuracy: 0.8347
# Epoch 37/100
# 800/800 [==============================] - 1s 800us/step - loss: 0.4015 - accuracy: 0.8366
# 800/800 [==============================] - 1s 746us/step - loss: 0.3999 - accuracy: 0.8350
# Epoch 72/100
# 800/800 [==============================] - 1s 827us/step - loss: 0.4002 - accuracy: 0.8339
# Epoch 73/100
# 800/800 [==============================] - 1s 752us/step - loss: 0.4003 - accuracy: 0.8351
# Epoch 74/100
# 800/800 [==============================] - 1s 797us/step - loss: 0.4004 - accuracy: 0.8365
# Epoch 75/100
# 800/800 [==============================] - 1s 758us/step - loss: 0.3998 - accuracy: 0.8346
# Epoch 76/100
# 800/800 [==============================] - 1s 720us/step - loss: 0.3995 - accuracy: 0.8339
# Epoch 77/100
# 800/800 [==============================] - 1s 732us/step - loss: 0.4002 - accuracy: 0.8370
# Epoch 78/100
# 800/800 [==============================] - 1s 681us/step - loss: 0.3994 - accuracy: 0.8346
# Epoch 79/100
# 800/800 [==============================] - 1s 691us/step - loss: 0.4003 - accuracy: 0.8340
# Epoch 80/100
# 800/800 [==============================] - 1s 749us/step - loss: 0.4002 - accuracy: 0.8355
# Epoch 81/100
# 800/800 [==============================] - 1s 674us/step - loss: 0.4000 - accuracy: 0.8365
# Epoch 82/100
# 800/800 [==============================] - 1s 738us/step - loss: 0.3999 - accuracy: 0.8363
# Epoch 83/100
# 800/800 [==============================] - 1s 693us/step - loss: 0.3997 - accuracy: 0.8371
# Epoch 84/100
# 800/800 [==============================] - 1s 802us/step - loss: 0.4000 - accuracy: 0.8372
# Epoch 85/100
# 800/800 [==============================] - 1s 732us/step - loss: 0.4000 - accuracy: 0.8361
# Epoch 86/100
# 800/800 [==============================] - 1s 765us/step - loss: 0.4001 - accuracy: 0.8364
# Epoch 87/100
# 800/800 [==============================] - 1s 793us/step - loss: 0.3996 - accuracy: 0.8344
# Epoch 88/100
# 800/800 [==============================] - 1s 685us/step - loss: 0.4003 - accuracy: 0.8360
# Epoch 89/100
# 800/800 [==============================] - 1s 683us/step - loss: 0.4002 - accuracy: 0.8355
# Epoch 90/100
# 800/800 [==============================] - 1s 753us/step - loss: 0.4000 - accuracy: 0.8351
# Epoch 91/100
# 800/800 [==============================] - 1s 858us/step - loss: 0.3993 - accuracy: 0.8356
# Epoch 92/100
# 800/800 [==============================] - 1s 717us/step - loss: 0.3996 - accuracy: 0.8353
# Epoch 93/100
# 800/800 [==============================] - 1s 798us/step - loss: 0.3996 - accuracy: 0.8363
# Epoch 94/100
# 800/800 [==============================] - 1s 718us/step - loss: 0.3996 - accuracy: 0.8361
# Epoch 95/100
# 800/800 [==============================] - 1s 665us/step - loss: 0.4001 - accuracy: 0.8380
# Epoch 96/100
# 800/800 [==============================] - 1s 691us/step - loss: 0.3997 - accuracy: 0.8360
# Epoch 97/100
# 800/800 [==============================] - 1s 675us/step - loss: 0.4000 - accuracy: 0.8354
# Epoch 98/100
# 800/800 [==============================] - 1s 682us/step - loss: 0.3999 - accuracy: 0.8364
# Epoch 99/100
# 800/800 [==============================] - 1s 803us/step - loss: 0.3998 - accuracy: 0.8360
# Epoch 100/100
# 800/800 [==============================] - 1s 859us/step - loss: 0.3997 - accuracy: 0.8349

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 63/63 [==============================] - 0s 830us/step

# %%
print(y_pred)
# Out:
# [[False]
#  [False]
#  [False]
#  ...
#  [False]
#  [False]
#  [False]]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(Y_test, y_pred)

# %%
print(cm)
# Out:
# [[1537   58]
#  [ 255  150]]

# %%
accuracy_score(Y_test, y_pred)
# Out:
# 0.8435
